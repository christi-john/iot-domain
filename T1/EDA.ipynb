# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
df = pd.read_csv('heart.csv') #read data from CSV file

# %%
# data overview of first five rows
df.head()
#df.head(2)
#df.tail()
#len(df)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
# Overall statistics
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
#df.isna().any()# display the data set coloum having nan values
df.dropna() # Drop rows with any column having NA/null data
len(df) #length of rows 
df.fillna(10) #Replace all NA/null data with value.
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#dropping missing value
df.dropna().any()
# Out:
# age         True
# sex         True
# cp          True
# trestbps    True
# chol        True
# fbs         True
# restecg     True
# thalach     True
# exang       True
# oldpeak     True
# slope       True
# ca          True
# thal        True
# target      True
# dtype: bool

# %%
#df['chol']  # Read single cloumn
#df[['thalach','exang']]  # Read multiple columns
#getting max,min and mean value of column
#df['fbs'].mean()
#df[['chol','thal']].corr()
df[['age','trestbps']].corr()
# Out:
#                age  trestbps
# age       1.000000  0.271121
# trestbps  0.271121  1.000000

# %%
# Selecting rows by their location
df.iloc[:3]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0

# %%
# Selecting columns by their location
x=df.iloc[:,:2]
#print(type(x))
print(x)
# Out:
#       age  sex
# 0      52    1
# 1      53    1
# 2      70    1
# 3      61    1
# 4      62    0
# ...   ...  ...
# 1020   59    1
# 1021   60    1
# 1022   47    1
# 1023   50    0
# 1024   54    1
#
# [1025 rows x 2 columns]

# %%
# Categorical data
df["chol"].value_counts()
#Count the number of non-NA values
df['cp'].count()
# Out:
# 1025

# %%
# Box Plot
#sns.boxplot(x='num-of-cylinders',y='price',data=df)
#sns.boxplot(x='num-of-cylinders',y='price',data=df, vert = False, grid = True )
sns.boxplot(x='restecg',y='thalach',data=df)
# Out:
# <AxesSubplot:xlabel='restecg', ylabel='thalach'>

# %%
#df[['price','horsepower']].plot.box(vert = False, grid = True)
df[['restecg','fbs']].plot.box()
# Out:
# <AxesSubplot:>

# %%
# Scatter plots
plt.scatter(df['chol'],df['thalach'])
plt.xlabel('Cholesterol')
plt.ylabel('Max. heart-rate')
plt.show()

# %%
# Histogram
count,bin_edges = np.histogram(df['trestbps'])
df['trestbps'].plot(kind='hist',xticks=bin_edges)
plt.xlabel('Value of resting blood pressure (in mm Hg)')
plt.ylabel('age')
plt.grid()
plt.show()

# %%
# Grouping
df_temp = df[['chol','thalach','age']]
df_group = df_temp.groupby(['chol','thalach'],as_index=False).mean()
df_group
#df_temp
# Out:
#      chol  thalach   age
# 0     126      173  57.0
# 1     131      115  57.0
# 2     141      175  44.0
# 3     149      125  71.0
# 4     149      126  49.0
# ..    ...      ...   ...
# 291   394      157  62.0
# 292   407      154  63.0
# 293   409      150  56.0
# 294   417      157  65.0
# 295   564      160  67.0
#
# [296 rows x 3 columns]

# %%
# Correlation matrix
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...
